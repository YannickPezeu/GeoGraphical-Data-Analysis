# %% [markdown]
# <a href="https://colab.research.google.com/github/Provatiscus/Coursera_Capstone/blob/master/Capstone_Week_3_second.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook will be mainly used for the capstone project.

# %%
import numpy as np
import pandas as pd

# %%
print( "Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# We import BeautifulSoup that we will use to scrape the Wikipedia page
# We import urllib.request which will be use to download the Wikipedia page html code

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
html = urlopen("http://www.google.com/").read()
print(html)
quote_page = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')
print(soup)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2020/december-holidays-days-2-30-6753651837108830.3-law.gif" itemprop="image"><meta content="December Holidays" property="twitter:title"><meta content="December Holidays 2020 #GoogleDoodle" property="twitter:description"><meta content="December Holidays 2020 #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2020/december-holidays-days-2-30-6753651837108830.3-2xa.gif" property="twitter:image"><meta content="https://www
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating the dataframe df

# %%
df = pd.DataFrame(columns = ["Postal Code", "Borough", "Neighbourhood"])
df
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# We are filling the dataframe with a single line of code thanks to BeautifulSoup

# %%
for i, tr in enumerate(soup.find_all('tr')[1:-5]):
  df.loc[i] = [tr.find_all('td')[i].text.replace('\n', '') for i in range(3)]

# %%
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# We replace the 'Not assigned with zeros'.

# %%
df.replace('Not assigned', 0, inplace = True)
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A                 0                          0
# 1         M2A                 0                          0
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# We drop all lines with the Borough not assigned and we verify that all the Neighbourhoods are filled

# %%
df = df.loc[df['Borough']!=0]
print((df["Neighbourhood"] == 0).sum())
df.reset_index(inplace = True)
df = df.drop('index', axis = 1)
df.head()
# Out:
# 0
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# We print the shape of the dataframe as expected

# %%
print( "the shape of the DataFrame is: ", df.shape)
# Out:
# the shape of the DataFrame is:  (103, 3)

# %% [markdown]
# #Second Part

# %% [markdown]
# Mounting my Drive as I am on Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/Capstone
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Capstone'
# /content/drive/My Drive/Capstone

# %% [markdown]
# Taking the file from the drive

# %%
geo_df = pd.read_csv("Geospatial_Coordinates.csv")

# %% [markdown]
# Joining the two dataframe on Postal Code

# %%
df2 = df.join(geo_df.set_index('Postal Code'), on = 'Postal Code')
df2.head()
# Out:
#   Postal Code           Borough  ...   Latitude  Longitude
# 0         M3A        North York  ...  43.753259 -79.329656
# 1         M4A        North York  ...  43.725882 -79.315572
# 2         M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3         M6A        North York  ...  43.718518 -79.464763
# 4         M7A  Downtown Toronto  ...  43.662301 -79.389494
#
# [5 rows x 5 columns]
